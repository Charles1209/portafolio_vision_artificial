# %% [markdown]
# # Analizando un poco la data

# %%
#https://github.com/stephfz/data-manandvis-pandas-matplotlib/blob/master/data-manipulation-visualization-pandas-matplotlib.ipynb
#import all libraries!
import pandas as pd # el as pd es un alias, hace el codigo un poco mas corto

# %%
# importemos (carguemos en memoria) la información
# pandas carga la información como un dataframe o matriz, tal como si tuvieramos una hoja de calculo

data = pd.read_csv('datasets/titanic.csv')

#previsualicemos la data
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#cual es la dimension (filas, columnas) de mi dataframe?
print (data.shape)

# Conteo agrupado de valores dentro de una columna
print (data['Cabin'].value_counts())
print(data.Cabin)

#cabin = data['Cabin']
#print (cabin)
# Out:
# (891, 12)
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# Tengo datos completos para todos los registros?
# el metodo count cuanta cada registro(fila) que tenga datos
# podemos ver que por ejemplo para la columna Cabin tengo algunos registros sin datos
print (data.count())
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# Pero tener datos, no significa tener datos "limpios"
# Podemos ver en la previsualizacion que para la columna Cabin tengo algunos NaN, el cual en python 
# es interpretado como un valor nulo o Null, lo podría traer problemas cuando analice la información
# contemos cuantos datos nulos tenemos

# 1. Obtener los nombres de las columnas como una lista
col_names = data.columns.tolist()
# 2. Iterar sobre la lista
for column in col_names:
    print ("Valores nulos en <{0}>: {1}".format(column, data[column].isnull().sum()) )
# Out:
# Valores nulos en <PassengerId>: 0
# Valores nulos en <Survived>: 0
# Valores nulos en <Pclass>: 0
# Valores nulos en <Name>: 0
# Valores nulos en <Sex>: 0
# Valores nulos en <Age>: 177
# Valores nulos en <SibSp>: 0
# Valores nulos en <Parch>: 0
# Valores nulos en <Ticket>: 0
# Valores nulos en <Fare>: 0
# Valores nulos en <Cabin>: 687
# Valores nulos en <Embarked>: 2

# %%
# Imagina que para fines de simplicidad quieres reemplazar el female, male por F, M

# 1. Creamos un diccionario con los valores originales y los valores de reemplazo
d = {'male' : 'M', 'female' : 'F'}

# 2. Utilizamos un lambda para el reemplazo, en una sola linea
data['Sex'] = data['Sex'].apply(lambda x:d[x])

# verificar el cambio
data['Sex'].head()
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    M
# Name: Sex, dtype: object

# %%
# Una forma más sencilla de acceder a las columnas
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# Podemos dar un vistazo a la distribución de los datos
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Vemos que el minimo en Fare (precio) es 0 
# Cuantos no pagaron?
data[data.Fare == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name Sex  \
# 179          180         0       3               Leonard, Mr. Lionel   M
# 263          264         0       1             Harrison, Mr. William   M
# 271          272         1       3      Tornquist, Mr. William Henry   M
# 277          278         0       2       Parkes, Mr. Francis "Frank"   M
# 302          303         0       3   Johnson, Mr. William Cahoone Jr   M
# 413          414         0       2    Cunningham, Mr. Alfred Fleming   M
# 466          467         0       2             Campbell, Mr. William   M
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"   M
# 597          598         0       3               Johnson, Mr. Alfred   M
# 633          634         0       1     Parr, Mr. William Henry Marsh   M
# 674          675         0       2        Watson, Mr. Ennis Hastings   M
# 732          733         0       2              Knight, Mr. Robert J   M
# 806          807         0       1            Andrews, Mr. Thomas Jr   M
# 815          816         0       1                  Fry, Mr. Richard   M
# 822          823         0       1   Reuchlin, Jonkheer. John George   M
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 179  36.0      0      0    LINE   0.0   NaN        S
# 263  40.0      0      0  112059   0.0   B94        S
# 271  25.0      0      0    LINE   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S
# 413   NaN      0      0  239853   0.0   NaN        S
# 466   NaN      0      0  239853   0.0   NaN        S
# 481   NaN      0      0  239854   0.0   NaN        S
# 597  49.0      0      0    LINE   0.0   NaN        S
# 633   NaN      0      0  112052   0.0   NaN        S
# 674   NaN      0      0  239856   0.0   NaN        S
# 732   NaN      0      0  239855   0.0   NaN        S
# 806  39.0      0      0  112050   0.0   A36        S
# 815   NaN      0      0  112058   0.0  B102        S
# 822  38.0      0      0   19972   0.0   NaN        S

# %%
# Agrupemos por Sobrevivencia y Sexo
pd.crosstab(data.Survived, data.Sex)
# Out:
# Sex         F    M
# Survived
# 0          81  468
# 1         233  109

# %%
# Como fue la sobreviviencia por clase, sexo
pclass_gender_survival_count_df = data.groupby( ['Pclass', 'Sex'] )['Survived'].sum()
pclass_gender_survival_count_df
# Out:
# Pclass  Sex
# 1       F      91
#         M      45
# 2       F      70
#         M      17
# 3       F      72
#         M      47
# Name: Survived, dtype: int64

# %% [markdown]
# # Visualicemos!

# %%
# Cuantos sobrevivieron

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
 
fig = plt.figure(figsize=(30,10)) #creamos un canvas o figura de 30x10 pixeles

# queremos ver un plot al costado del otro, para esto pensemos en una grilla (celdas)
plt.subplot2grid((2,3),(0,0))
data.Survived.value_counts().plot(kind='bar', alpha=0.5)
plt.title('Sobrevivieron - cuenta total -')

# Hay manera un poco mas amigable de interpretar datos....con porcentajes!
plt.subplot2grid((2,3),(0,1))
data.Survived.value_counts(normalize = True).plot(kind='bar', alpha=0.5)
plt.title('Sobrevivieron - porcentaje total -')

plt.show()

# %%
#Sobrevivieron más hombres o más mujeres?
fig = plt.figure(figsize=(30,10))
data.Sex[data.Survived == 1].value_counts(normalize = True).plot(kind='barh', alpha=0.5, color='b')
plt.title('Sobrevivieron - Male vs Female -')
plt.show()

# %%
# Que relacion hay entre sobrevivencia y edad de los sobrevivientes
fig = plt.figure(figsize=(6,8))
plt.scatter(data.Survived, data.Age, alpha=0.5, color='#808000')
plt.show()

# %%
# La clase del ticket fue un factor de sobrevivencia (si viste Titanic, ya lo sabes!)
fig = plt.figure(figsize=(10,5))
#colors bgrcmykw
data.Pclass[data.Survived == 1 ].value_counts(normalize = True).plot(kind='bar', alpha=0.5, color='r')
plt.title('Sobrevivientes por Clase de Ticket')
plt.show()

# %%
# Habra alguna relacion entre tipo de ticket y edad? (Poder Adquisitivo)
fig = plt.figure(figsize=(20,10))

for t_class in [1,2,3]:
    data.Age[data.Pclass == t_class].plot(kind='kde')
    
plt.legend(("1ra. Clase", "2da. Clase", "3ra.Clase"))  
plt.show()

# La linea de la 1ra clase, nos muestra que el promedio de edad del comprador es de 40 annios
# La linea de la 3ra clase, tiene un promedio mucho mas joven

# Podriamos hacer una inferencia temprana y decir que los hombres que salvaron fueron 
# en su mayoria ricos y > 30 annios

# %%
data[data.Age < 1]
# Out:
#      PassengerId  Survived  Pclass                             Name Sex   Age  \
# 78            79         1       2    Caldwell, Master. Alden Gates   M  0.83
# 305          306         1       1   Allison, Master. Hudson Trevor   M  0.92
# 469          470         1       3    Baclini, Miss. Helene Barbara   F  0.75
# 644          645         1       3           Baclini, Miss. Eugenie   F  0.75
# 755          756         1       2        Hamalainen, Master. Viljo   M  0.67
# 803          804         1       3  Thomas, Master. Assad Alexander   M  0.42
# 831          832         1       2  Richards, Master. George Sibley   M  0.83
#
#      SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78       0      2  248738   29.0000      NaN        S
# 305      1      2  113781  151.5500  C22 C26        S
# 469      2      1    2666   19.2583      NaN        C
# 644      2      1    2666   19.2583      NaN        C
# 755      1      1  250649   14.5000      NaN        S
# 803      0      1    2625    8.5167      NaN        C
# 831      1      1   29106   18.7500      NaN        S
